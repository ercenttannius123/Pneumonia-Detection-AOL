# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

dataset_path = "E:\Semester 3\AI\AOL_AI\CNN\chest_xray"

for root, dirs, files in os.walk(dataset_path):
    print(f"{root} -> {len(files)} files")
# Any results you write to the current directory are saved as output.
# Out:
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray -> 0 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\test -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\test\NORMAL -> 234 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\test\PNEUMONIA -> 390 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\train -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\train\NORMAL -> 1342 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\train\PNEUMONIA -> 3876 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\val -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\val\NORMAL -> 9 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\chest_xray\val\PNEUMONIA -> 9 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\test -> 0 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\test\NORMAL -> 234 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\test\PNEUMONIA -> 390 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\train -> 0 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\train\NORMAL -> 1341 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\train\PNEUMONIA -> 3875 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\val -> 0 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\val\NORMAL -> 8 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\val\PNEUMONIA -> 8 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray -> 3 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\test -> 3 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\test\NORMAL -> 234 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\test\PNEUMONIA -> 390 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\train -> 3 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\train\NORMAL -> 1342 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\train\PNEUMONIA -> 3876 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\val -> 1 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\val\NORMAL -> 9 files
# E:\Semester 3\AI\AOL_AI\CNN\chest_xray\__MACOSX\chest_xray\val\PNEUMONIA -> 9 files

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Dense, Conv2D, MaxPool2D,Flatten, Dropout, BatchNormalization)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import cv2
import os

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_training_data(data_dir):
    data = []
    for label in labels:
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)

        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(
                    os.path.join(path, img),
                    cv2.IMREAD_GRAYSCALE
                )
                resized_arr = cv2.resize(
                    img_arr, (img_size, img_size)
                )
                data.append((resized_arr, class_num))  # tuple
            except Exception as e:
                print(e)

    return data   # ⬅️ LIST, BUKAN numpy

# %%
train = get_training_data("E:/Semester 3/AI/AOL_AI/CNN/chest_xray/train")
test = get_training_data("E:/Semester 3/AI/AOL_AI/CNN/chest_xray/test")
val = get_training_data("E:/Semester 3/AI/AOL_AI/CNN/chest_xray/val")

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    else:
        l.append("Normal")

sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# <Axes: xlabel='count'>

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'NORMAL')

# %%
x_train = []
y_train = []

x_val = []
y_val = []

x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)

for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
    
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
# With data augmentation to prevent overfitting and handling the imbalance in dataset

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 30,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False)  # randomly flip images


datagen.fit(x_train)

# %%
model = Sequential()
model.add(Conv2D(32 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (150,150,1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.1))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(64 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(128 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Conv2D(256 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
model.add(MaxPool2D((2,2) , strides = 2 , padding = 'same'))
model.add(Flatten())
model.add(Dense(units = 128 , activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(units = 1 , activation = 'sigmoid'))
model.compile(optimizer = "rmsprop" , loss = 'binary_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 150, 150, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 150, 150, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 75, 75, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 75, 75, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 75, 75, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 75, 75, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 38, 38, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 38, 38, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 38, 38, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 19, 19, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 19, 19, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 19, 19, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 19, 19, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 10, 10, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 10, 10, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 10, 10, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 5, 5, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6400)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       819,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,246,401 (4.75 MB)
#  Trainable params: 1,245,313 (4.75 MB)
#  Non-trainable params: 1,088 (4.25 KB)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience = 2, verbose=1,factor=0.3, min_lr=0.000001)

# %%
history = model.fit(datagen.flow(x_train,y_train, batch_size = 32) ,epochs = 30 , validation_data = datagen.flow(x_val, y_val) ,callbacks = [learning_rate_reduction])
# Out:
# Epoch 1/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 61s 342ms/step - accuracy: 0.8275 - loss: 0.5584 - val_accuracy: 0.5000 - val_loss: 19.7542 - learning_rate: 0.0010
# Epoch 2/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 333ms/step - accuracy: 0.8915 - loss: 0.2731 - val_accuracy: 0.5000 - val_loss: 41.1653 - learning_rate: 0.0010
# Epoch 3/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - accuracy: 0.9186 - loss: 0.2251
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 328ms/step - accuracy: 0.9212 - loss: 0.2270 - val_accuracy: 0.5000 - val_loss: 7.1787 - learning_rate: 0.0010
# Epoch 4/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 56s 341ms/step - accuracy: 0.9515 - loss: 0.1402 - val_accuracy: 0.5000 - val_loss: 7.8369 - learning_rate: 3.0000e-04
# Epoch 5/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 357ms/step - accuracy: 0.9515 - loss: 0.1330 - val_accuracy: 0.5625 - val_loss: 2.1824 - learning_rate: 3.0000e-04
# Epoch 6/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 335ms/step - accuracy: 0.9592 - loss: 0.1179 - val_accuracy: 0.5000 - val_loss: 10.9248 - learning_rate: 3.0000e-04
# Epoch 7/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9568 - loss: 0.1245
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 334ms/step - accuracy: 0.9557 - loss: 0.1324 - val_accuracy: 0.5000 - val_loss: 6.1713 - learning_rate: 3.0000e-04
# Epoch 8/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 331ms/step - accuracy: 0.9594 - loss: 0.1050 - val_accuracy: 0.5625 - val_loss: 0.7479 - learning_rate: 9.0000e-05
# Epoch 9/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - accuracy: 0.9644 - loss: 0.1111
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 53s 324ms/step - accuracy: 0.9659 - loss: 0.1044 - val_accuracy: 0.5625 - val_loss: 1.6320 - learning_rate: 9.0000e-05
# Epoch 10/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 354ms/step - accuracy: 0.9651 - loss: 0.1037 - val_accuracy: 0.6875 - val_loss: 0.7139 - learning_rate: 2.7000e-05
# Epoch 11/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 347ms/step - accuracy: 0.9691 - loss: 0.0916 - val_accuracy: 0.8125 - val_loss: 0.4232 - learning_rate: 2.7000e-05
# Epoch 12/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 333ms/step - accuracy: 0.9670 - loss: 0.0960 - val_accuracy: 0.6250 - val_loss: 1.4630 - learning_rate: 2.7000e-05
# Epoch 13/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step - accuracy: 0.9694 - loss: 0.0854
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 338ms/step - accuracy: 0.9684 - loss: 0.0916 - val_accuracy: 0.5625 - val_loss: 1.0630 - learning_rate: 2.7000e-05
# Epoch 14/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.9684 - loss: 0.1014 - val_accuracy: 0.5625 - val_loss: 0.8040 - learning_rate: 8.1000e-06
# Epoch 15/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.9692 - loss: 0.0918
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 334ms/step - accuracy: 0.9674 - loss: 0.0978 - val_accuracy: 0.5625 - val_loss: 0.7741 - learning_rate: 8.1000e-06
# Epoch 16/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 333ms/step - accuracy: 0.9688 - loss: 0.0858 - val_accuracy: 0.6875 - val_loss: 1.2103 - learning_rate: 2.4300e-06
# Epoch 17/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9733 - loss: 0.0752
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1e-06.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.9714 - loss: 0.0795 - val_accuracy: 0.6875 - val_loss: 0.5207 - learning_rate: 2.4300e-06
# Epoch 18/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 355ms/step - accuracy: 0.9709 - loss: 0.0827 - val_accuracy: 0.5625 - val_loss: 0.9104 - learning_rate: 1.0000e-06
# Epoch 19/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 335ms/step - accuracy: 0.9684 - loss: 0.0928 - val_accuracy: 0.6250 - val_loss: 0.8862 - learning_rate: 1.0000e-06
# Epoch 20/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 331ms/step - accuracy: 0.9709 - loss: 0.0780 - val_accuracy: 0.6875 - val_loss: 0.5702 - learning_rate: 1.0000e-06
# Epoch 21/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 331ms/step - accuracy: 0.9711 - loss: 0.0823 - val_accuracy: 0.6250 - val_loss: 0.9428 - learning_rate: 1.0000e-06
# Epoch 22/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 333ms/step - accuracy: 0.9720 - loss: 0.0846 - val_accuracy: 0.5625 - val_loss: 0.7293 - learning_rate: 1.0000e-06
# Epoch 23/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 353ms/step - accuracy: 0.9699 - loss: 0.0841 - val_accuracy: 0.5000 - val_loss: 1.3573 - learning_rate: 1.0000e-06
# Epoch 24/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 334ms/step - accuracy: 0.9703 - loss: 0.0871 - val_accuracy: 0.5625 - val_loss: 1.0805 - learning_rate: 1.0000e-06
# Epoch 25/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 54s 332ms/step - accuracy: 0.9718 - loss: 0.0856 - val_accuracy: 0.5625 - val_loss: 0.6965 - learning_rate: 1.0000e-06
# Epoch 26/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 336ms/step - accuracy: 0.9672 - loss: 0.0892 - val_accuracy: 0.6875 - val_loss: 0.7991 - learning_rate: 1.0000e-06
# Epoch 27/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 56s 343ms/step - accuracy: 0.9716 - loss: 0.0803 - val_accuracy: 0.5625 - val_loss: 1.3266 - learning_rate: 1.0000e-06
# Epoch 28/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 350ms/step - accuracy: 0.9672 - loss: 0.0873 - val_accuracy: 0.6250 - val_loss: 0.5857 - learning_rate: 1.0000e-06
# Epoch 29/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 59s 363ms/step - accuracy: 0.9684 - loss: 0.0889 - val_accuracy: 0.6875 - val_loss: 0.6022 - learning_rate: 1.0000e-06
# Epoch 30/30
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 336ms/step - accuracy: 0.9668 - loss: 0.0875 - val_accuracy: 0.6250 - val_loss: 0.9518 - learning_rate: 1.0000e-06

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0])
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - accuracy: 0.8974 - loss: 0.2814
# Loss of the model is -  0.2814023196697235
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.8974 - loss: 0.2814
# Accuracy of the model is -  89.74359035491943 %

# %%
epochs = [i for i in range(30)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
pred_prob = model.predict(x_test)
predictions = (pred_prob >= 0.5).astype(int).ravel()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step

# %%
print(classification_report(y_test, predictions, target_names = ['Pneumonia (Class 0)','Normal (Class 1)']))
# Out:
#                      precision    recall  f1-score   support
#
# Pneumonia (Class 0)       0.91      0.93      0.92       390
#    Normal (Class 1)       0.88      0.84      0.86       234
#
#            accuracy                           0.90       624
#           macro avg       0.89      0.89      0.89       624
#        weighted avg       0.90      0.90      0.90       624

# %%
cm = confusion_matrix(y_test,predictions)
cm
# Out:
# array([[363,  27],
#        [ 37, 197]])

# %%
cm = pd.DataFrame(cm , index = ['0','1'] , columns = ['0','1'])

# %%
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='',xticklabels = labels,yticklabels = labels)
# Out:
# <Axes: >

# %%
correct = np.nonzero(predictions == y_test)[0]
incorrect = np.nonzero(predictions != y_test)[0]

# %%
plt.figure(figsize=(8, 10))  

i = 0
for c in correct[:6]:
    plt.subplot(3, 2, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray")
    plt.title(
        f"Predicted Class: {predictions[c]}  Actual Class: {y_test[c]}",
        fontsize=10
    )
    i += 1

plt.tight_layout()
plt.show()

# %%
i = 0
for c in incorrect[:6]:
    plt.subplot(3,2,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_test[c].reshape(150,150), cmap="gray", interpolation='none')
    plt.title("Predicted Class {},\nActual Class {}".format(predictions[c], y_test[c]))
    plt.tight_layout()
    i += 1

# %%
model.save("chest_xray_model.keras")
print("Model saved successfully!")
# Out:
# Model saved successfully!
